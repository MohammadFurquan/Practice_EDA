# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sn

# %%
df = pd.read_csv("sample_data_cleaning.csv")

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
df.shape
# Out:
# (10, 7)

# %%
df.size
# Out:
# 70

# %%
df.isna()
# Out:
#     Name    Age  Gender  Salary  Department  Joining Date  Rating
# 0  False  False   False   False       False         False   False
# 1  False  False   False   False       False         False   False
# 2  False  False    True   False       False          True   False
# 3  False   True   False   False       False         False   False
# 4  False  False   False    True       False         False   False
# 5  False  False   False   False       False         False    True
# 6  False  False   False   False       False         False   False
# 7   True  False   False   False       False         False   False
# 8  False   True   False   False        True         False   False
# 9  False  False    True   False       False          True   False

# %%
df.isnull()
# Out:
#     Name    Age  Gender  Salary  Department  Joining Date  Rating
# 0  False  False   False   False       False         False   False
# 1  False  False   False   False       False         False   False
# 2  False  False    True   False       False          True   False
# 3  False   True   False   False       False         False   False
# 4  False  False   False    True       False         False   False
# 5  False  False   False   False       False         False    True
# 6  False  False   False   False       False         False   False
# 7   True  False   False   False       False         False   False
# 8  False   True   False   False        True         False   False
# 9  False  False    True   False       False          True   False

# %%
df.isnull().count()
# Out:
# Name            10
# Age             10
# Gender          10
# Salary          10
# Department      10
# Joining Date    10
# Rating          10
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name            1
# Age             2
# Gender          2
# Salary          1
# Department      1
# Joining Date    2
# Rating          1
# dtype: int64

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
df['Name'].fillna(df['Name'].mode())
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7        Ivy
# 8        Ivy
# 9       Jack
# Name: Name, dtype: object

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
# df.dropna(axis = 1 , inplace = True)

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
import matplotlib.pyplot as plt

# %%
df['Salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.show()

# %%
q1 = df['Salary'].quantile(0.25)
q3 = df['Salary'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df = df[(df['Salary'] >= lower_bound) & (df['Salary'] <= upper_bound)]

# %%
df['Salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
df
# Out:
#       Name   Age Gender   Salary Department Joining Date  Rating
# 0    Alice  25.0      F  50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M  60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN  70000.0         IT          NaN     4.2
# 3    David   NaN      M  80000.0    Finance   2021-03-22     4.8
# 6    Grace  29.0      F  65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M  70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F  75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN  50000.0    Finance          NaN     4.5

# %%
print(df.dtypes)
# Out:
# Name             object
# Age             float64
# Gender           object
# Salary          float64
# Department       object
# Joining Date     object
# Rating          float64
# dtype: object

# %%
df['column_name'] = df['column_name'].astype(float)  # Convert to float
df['date_column'] = pd.to_datetime(df['date_column'])  # Convert to datetime

# %%
print(df['category_column'].unique())

# %%
df.drop(columns=['irrelevant_column1', 'irrelevant_column2'], inplace=True)

# %%
df = df[df['column_name'] > 10]  # Keep rows where column value > 10

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data_cleaning.csv")

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
df.head()
# Out:
#       Name   Age Gender   Salary Department Joining Date  Rating
# 0    Alice  25.0      F  50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M  60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN  70000.0         IT          NaN     4.2
# 3    David   NaN      M  80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F      NaN    Finance   2018-11-05     3.7

# %%
df.tail()
# Out:
#     Name   Age Gender    Salary Department Joining Date  Rating
# 5  Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6  Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7    NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8    Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9   Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
df.shape
# Out:
# (10, 7)

# %%
df.size
# Out:
# 70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          9 non-null      object
#  1   Age           8 non-null      float64
#  2   Gender        8 non-null      object
#  3   Salary        9 non-null      float64
#  4   Department    9 non-null      object
#  5   Joining Date  8 non-null      object
#  6   Rating        9 non-null      float64
# dtypes: float64(3), object(4)
# memory usage: 692.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary', 'Department', 'Joining Date',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          9 non-null      object
#  1   Age           8 non-null      float64
#  2   Gender        8 non-null      object
#  3   Salary        9 non-null      float64
#  4   Department    9 non-null      object
#  5   Joining Date  8 non-null      object
#  6   Rating        9 non-null      float64
# dtypes: float64(3), object(4)
# memory usage: 692.0+ bytes

# %%
df.describe()
# Out:
#              Age         Salary    Rating
# count   8.000000       9.000000  9.000000
# mean   35.250000   68888.888889  4.166667
# std     8.940278   15567.951410  0.367423
# min    25.000000   50000.000000  3.700000
# 25%    28.750000   60000.000000  3.900000
# 50%    32.500000   70000.000000  4.100000
# 75%    41.250000   75000.000000  4.500000
# max    50.000000  100000.000000  4.800000

# %%
print(df.isnull().sum())
# Out:
# Name            1
# Age             2
# Gender          2
# Salary          1
# Department      1
# Joining Date    2
# Rating          1
# dtype: int64

# %%
import warnings

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7      NaN  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
df['Name'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Name, dtype: bool

# %%
df['Name'].fillna("Faizi", inplace = True)
# Out:
# C:\Users\mohammad furquan\AppData\Local\temp\ipykernel_14228\717284523.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Name'].fillna("Faizi", inplace = True)

# %%
df
# Out:
#       Name   Age Gender    Salary Department Joining Date  Rating
# 0    Alice  25.0      F   50000.0         HR   2020-01-15     4.5
# 1      Bob  30.0      M   60000.0         IT   2019-07-30     3.9
# 2  Charlie  35.0    NaN   70000.0         IT          NaN     4.2
# 3    David   NaN      M   80000.0    Finance   2021-03-22     4.8
# 4      Eve  45.0      F       NaN    Finance   2018-11-05     3.7
# 5    Frank  50.0      M  100000.0         HR   2017-06-10     NaN
# 6    Grace  29.0      F   65000.0         HR   2022-01-01     4.0
# 7    Faizi  40.0      M   70000.0         IT   2020-12-10     4.1
# 8      Ivy   NaN      F   75000.0        NaN   2019-05-20     3.8
# 9     Jack  28.0    NaN   50000.0    Finance          NaN     4.5

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot a histogram to check the distribution
sns.histplot(df['Age'], kde=True)
plt.show()

# %%
import seaborn as sns
sns.boxplot(x=df['Salary'])
# Out:
# <Axes: xlabel='Salary'>
